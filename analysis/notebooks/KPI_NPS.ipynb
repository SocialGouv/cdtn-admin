# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # KPI NPS

# %% [markdown]
# Score NPS du CDTN

# %% [markdown]
# ## Récupération des scores par jour

# %%
import requests
import pandas as pd
import re

# %%
from analysis.reports.nps_scores import get_nps_scores
df = get_nps_scores(date)

# %%
df
